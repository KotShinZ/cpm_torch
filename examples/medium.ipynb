# %%
import torch
from tqdm import tqdm

# %%
import os
import sys

sys.path.append(os.path.pardir)

# %%
from cpm_torch.CPM_Image import *
from cpm_torch.CPM import *

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPUを利用します: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("CPUを利用します")

config = CPM_config(
    size = (16, 16),  # 画像サイズ
    l_A=1.0,  # 面積エネルギー項の係数λ_A
    l_L=1.0,  # 周囲長エネルギー項の係数λ_L
    A_0=36.0,  # 目標細胞面積 A_0
    L_0=24.0,  # 目標細胞周囲長 L_0
    T=1.0,  # 温度パラメータ T
)
print(config.__dict__)
# Out:
# GPUを利用します: NVIDIA H100 PCIe
# {'size': (16, 16), 'dim': 2, 'height': 16, 'width': 16, 'depth': 1, 'l_A': 1.0, 'l_L': 1.0, 'A_0': 36.0, 'L_0': 24.0, 'T': 1.0}

# %% [markdown]
# ### 初期条件

# %%
cpm = CPM(config, device)  # CPMのインスタンスを作成
cpm.add_cell(8, 8)
imshow_map(cpm.map_tensor)  # 初期状態を表示

# %% [markdown]
# ### シュミレーション

# %%
step = 30      # シミュレーションのエポック数
mcs_per_step = 1 # 1エポックあたりのCPMステップ数
diffusion_steps = 5 # 1 CPMステップあたりの拡散ステップ数

# オプション: 動画記録用ライターの初期化
video_filename = '../results/cpm_torch_jp.mp4'
writer = LoopWriter(filename=video_filename, fps=10) # ループ動画ライター

# --- シミュレーション実行 ---
for i in tqdm(range(step), desc="ステップ"):
    for k in range(mcs_per_step):
        cpm.cpm_mcs_step()
        
    imshow_map(cpm.map_tensor)  # 各エポックの状態を表示
    cpm.print_cpm_bins()  # 各細胞の面積と周囲長を表示
    
    # --- 動画フレーム追加 ---
    frame_rgb = map_tensor_to_rgb(cpm.map_tensor)
    writer.add(frame_rgb)

writer.close()
imshow_map(cpm.map_tensor)
# Out:
# ステップ:   0%|          | 0/30 [00:00<?, ?it/s]
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# ステップ:   3%|▎         | 1/30 [00:00<00:05,  5.50it/s]
# 面積カウント: tensor([252.,   4.], device='cuda:0')
# 周囲長カウント: tensor([10., 10.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([246.,  10.], device='cuda:0')
# 周囲長カウント: tensor([16., 16.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([245.,  11.], device='cuda:0')
# 周囲長カウント: tensor([16., 16.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([238.,  18.], device='cuda:0')
# 周囲長カウント: tensor([22., 22.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([228.,  28.], device='cuda:0')
# 周囲長カウント: tensor([30., 30.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([223.,  33.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# ステップ:  30%|███       | 9/30 [00:00<00:00, 36.99it/s]
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([222.,  34.], device='cuda:0')
# 周囲長カウント: tensor([24., 24.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# ステップ:  57%|█████▋    | 17/30 [00:00<00:00, 52.53it/s]
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# ステップ:  83%|████████▎ | 25/30 [00:00<00:00, 60.40it/s]
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# 面積カウント: tensor([221.,  35.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# torch.Size([36, 9, 1])
# ステップ: 100%|██████████| 30/30 [00:00<00:00, 52.72it/s]
# 面積カウント: tensor([220.,  36.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
