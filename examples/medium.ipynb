# %%
import torch
from tqdm import tqdm

# %%
import os
import sys

sys.path.append(os.path.pardir)

# %%
from cpm_torch.CPM_Image import *
from cpm_torch.CPM import *

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPUを利用します: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("CPUを利用します")

config = CPM_config(
    size = (16, 16),  # 画像サイズ
    l_A=1.0,  # 面積エネルギー項の係数λ_A
    l_L=1.0,  # 周囲長エネルギー項の係数λ_L
    A_0=36.0,  # 目標細胞面積 A_0
    L_0=24.0,  # 目標細胞周囲長 L_0
    T=1.0,  # 温度パラメータ T
)
print(config.__dict__)
# Out:
# GPUを利用します: NVIDIA H100 PCIe
# {'size': (32, 32), 'dim': 2, 'height': 32, 'width': 32, 'depth': 1, 'l_A': 1.0, 'l_L': 1.0, 'A_0': 36.0, 'L_0': 24.0, 'T': 1.0}

# %% [markdown]
# ### 初期条件

# %%
cpm = CPM(config, device)  # CPMのインスタンスを作成
cpm.add_cell(8, 8)
imshow_map(cpm.map_tensor)  # 初期状態を表示

# %% [markdown]
# ### シュミレーション

# %%
step = 30      # シミュレーションのエポック数
mcs_per_step = 1 # 1エポックあたりのCPMステップ数
diffusion_steps = 5 # 1 CPMステップあたりの拡散ステップ数

# オプション: 動画記録用ライターの初期化
video_filename = '../results/cpm_torch_jp.mp4'
writer = LoopWriter(filename=video_filename, fps=10) # ループ動画ライター

# --- シミュレーション実行 ---
for i in tqdm(range(step), desc="ステップ"):
    for k in range(mcs_per_step):
        cpm.cpm_mcs_step()
        
    imshow_map(cpm.map_tensor)  # 各エポックの状態を表示
    cpm.print_cpm_bins()  # 各細胞の面積と周囲長を表示
    
    # --- 動画フレーム追加 ---
    frame_rgb = map_tensor_to_rgb(cpm.map_tensor)
    writer.add(frame_rgb)

writer.close()
imshow_map(cpm.map_tensor)
# Out:
# ステップ:   0%|          | 0/30 [00:00<?, ?it/s]
# ステップ:   3%|▎         | 1/30 [00:00<00:04,  6.90it/s]
# 面積カウント: tensor([1022.,    2.], device='cuda:0')
# 周囲長カウント: tensor([6., 6.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1022.,    2.], device='cuda:0')
# 周囲長カウント: tensor([6., 6.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1022.,    2.], device='cuda:0')
# 周囲長カウント: tensor([6., 6.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1016.,    8.], device='cuda:0')
# 周囲長カウント: tensor([14., 14.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1010.,   14.], device='cuda:0')
# 周囲長カウント: tensor([20., 20.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1006.,   18.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1001.,   23.], device='cuda:0')
# 周囲長カウント: tensor([24., 24.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1001.,   23.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([998.,  26.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# ステップ:  33%|███▎      | 10/30 [00:00<00:00, 47.82it/s]
# 面積カウント: tensor([1000.,   24.], device='cuda:0')
# 周囲長カウント: tensor([28., 28.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1009.,   15.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1012.,   12.], device='cuda:0')
# 周囲長カウント: tensor([30., 30.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1012.,   12.], device='cuda:0')
# 周囲長カウント: tensor([34., 34.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1004.,   20.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1005.,   19.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1005.,   19.], device='cuda:0')
# 周囲長カウント: tensor([30., 30.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1007.,   17.], device='cuda:0')
# 周囲長カウント: tensor([26., 26.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1005.,   19.], device='cuda:0')
# 周囲長カウント: tensor([36., 36.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1010.,   14.], device='cuda:0')
# 周囲長カウント: tensor([30., 30.], device='cuda:0')
# 細胞数: 1
# ステップ:  67%|██████▋   | 20/30 [00:00<00:00, 66.93it/s]
# 面積カウント: tensor([1012.,   12.], device='cuda:0')
# 周囲長カウント: tensor([30., 30.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1012.,   12.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1009.,   15.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1009.,   15.], device='cuda:0')
# 周囲長カウント: tensor([34., 34.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1008.,   16.], device='cuda:0')
# 周囲長カウント: tensor([34., 34.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1007.,   17.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1004.,   20.], device='cuda:0')
# 周囲長カウント: tensor([28., 28.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1010.,   14.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1009.,   15.], device='cuda:0')
# 周囲長カウント: tensor([32., 32.], device='cuda:0')
# 細胞数: 1
# 面積カウント: tensor([1009.,   15.], device='cuda:0')
# 周囲長カウント: tensor([28., 28.], device='cuda:0')
# 細胞数: 1
# ステップ: 100%|██████████| 30/30 [00:00<00:00, 64.36it/s]
# 面積カウント: tensor([1008.,   16.], device='cuda:0')
# 周囲長カウント: tensor([34., 34.], device='cuda:0')
# 細胞数: 1
